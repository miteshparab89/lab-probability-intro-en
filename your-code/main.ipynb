# %% [markdown]
# # Probability

# %% [markdown]
# ## Challenge 1
# There is a box with 10 white balls, 12 red balls and 8 black balls. Calculate the probability of:
# * Taking a white ball out.
# * Taking a white ball on first extraction and a black ball out on second extraction without replacing the first one.
# * Taking a white ball on first extraction and a black ball out on second extraction replacing the first one.
# * Taking 3 balls and them being all different colours.

# %%
import math

white = 10
red = 12
black = 8
total = white + red + black

# 1️ Probability of taking a white ball

p_white = white / total
p_white = 10 / 30
print("1 P(white) =", p_white)

# 2 White first, then Black (without replacement)
p_white_then_black_no_replace = (white / total) * (black / (total - 1))
p_white_black_no_replace = (10 / 30) * (8 / 29)
print("2. P(white then black, no replacement) =", p_white_then_black_no_replace)

# 3 White first, Black second (with replacement)
p_white_then_black_replace = (white / total) * (black / total)
p_white_black_replace = (10 / 30) * (8 / 30)
print("3. P(white then black, with replacement) =", p_white_then_black_replace)

# 4. 3 balls all different colors (without replacement)
favorable = math.comb(white, 1) * math.comb(red, 1) * math.comb(black, 1)
total_ways = math.comb(total, 3)
p_all_diff = (6 * 10 * 12 * 8) / (30 * 29 * 28)


print("4. P(all 3 different colors) =", p_all_diff)
# Out:
# 1 P(white) = 0.3333333333333333
# 2. P(white then black, no replacement) = 0.09195402298850575
# 3. P(white then black, with replacement) = 0.08888888888888888
# 4. P(all 3 different colors) = 0.23645320197044334

# %% [markdown]
# ## Challenge 2
#
# You want to go on picnic on Saturday. You hate rain, and would know to plan your weekend. To help you make a decision, you gather the following data about rainy days:
#
# * 40% of all days are cloudy.
# * About 50% of cloudy days are rainy.
# * About 20% of non-cloudy days are rainy.
#
# What is the chance of rain during next Saturday?

# %%
# Given probabilities
p_cloudy = 0.4
p_rain_given_cloudy = 0.5
p_rain_given_not_cloudy = 0.2

p_not_cloudy = 1 - p_cloudy

# Total probability of rain
p_rain = (p_rain_given_cloudy * p_cloudy) + (p_rain_given_not_cloudy * p_not_cloudy)

print("Probability of rain on Saturday:", p_rain)
print("In percentage:", p_rain*100, "%")
# Out:
# Probability of rain on Saturday: 0.32
# In percentage: 32.0 %

# %% [markdown]
# ## Challenge 3
#
# A and B are events of a probability such that $P(A) = 0.3$, $P(B) = 0.6$ and $P(A \cap B) = 0.1$
#
# Which of the following statements are true?
# **HINT: draw a big Venn Diagram by your side**
# * $P(\overline{A}) = 0.7$
# * $P(A \cup B) = 0.6$
# * $P(A \cap \overline{B}) = 0.2$
# * $P(A \cup \overline{A}) = 1$
# * $P(A \cap (B \cup \overline{B})) = 0.4$
# * $P(\overline{A} \cap \overline{B}) = 0.3$
# * $P(\overline{A \cap B}) = 0.9$

# %%
1. True
3. True

4 True
7 True

# %% [markdown]
# ## Challenge 4
#
#  * If someone flies to China, the probability of getting Covid is 1%
#  * If someone flies to Italy, the probability of getting Covid is 20%
#
# I roll 1 dice with numbers 1, 2, 3, 4, 5, 6:
#  * If 1: I fly to Italy
#  * If not 1: I fly to China
#
# During my trip, I got Covid. What is the probability that I flew to China?

# %%
# Dice outcomes
p_italy = 1/6       # Only rolling 1
p_china = 5/6       # Rolling 2,3,4,5,6

# Covid probabilities
p_covid_italy = 0.2
p_covid_china = 0.01

# Total probability of Covid
p_covid = (p_covid_italy * p_italy) + (p_covid_china * p_china)
print("Total probability of getting Covid:", p_covid)

p_china_given_covid = (p_covid_china * p_china) / p_covid
print("Probability flew to China given Covid:", p_china_given_covid)
print("Percentage:", p_china_given_covid*100, "%")



# p_italy = 1/6 → only 1 dice outcome

# p_china = 5/6 → dice numbers 2–6

# Multiply flight probability × Covid probability to get joint probability

# Divide China & Covid probability by total Covid probability → gives chance that it was China given Covid
# Out:
# Total probability of getting Covid: 0.041666666666666664
# Probability flew to China given Covid: 0.2
# Percentage: 20.0 %

# %% [markdown]
# ## BONUS
#
# You roll 2 dice. What is the probability that the sum of the numbers is 7? And 8? And 9? Then simulate 10000 times and draw a countplot.

# %% [markdown]
# your explanation here

# %%
# YOUR CODE HERE
